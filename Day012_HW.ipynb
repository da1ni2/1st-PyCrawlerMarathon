# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 取出今天所有的發文
# * ② 如果想要依照類別分類，怎麼儲存會比較好？
# * ③ 哪一個類別的文章最多

# %% [markdown]
# ### ① 取出今天所有的發文

# %%
'''
Your Code
'''
url = 'https://www.ettoday.net/news/news-list-2019-12-9-0.htm'
import requests
from bs4 import BeautifulSoup
r = requests.get(url)
soup = BeautifulSoup(r.text , 'html5lib')
# Out:
# <h3><span class="date">2019/12/09 18:59</span><em class="tag c_sport">體育</em><a href="/news/20191209/1598109.htm" target="_blank">高中鋁聯／登板腎上腺素升！穀保賴沅晏滿壘拆彈成功</a></h3>

# %%
soup.find(class_ = 'part_list_2').find_all('h3')[0].find_all('em')[0].text
# Out:
# '體育'

# %%
for i in soup.find(class_ = 'part_list_2').find_all('h3'):
    print(f'{i.find(class_ = "date").text} 『 {i.find_all("em")[0].text} 』  {i.find_all("a")[0].text}')
# Out:
# 2019/12/09 18:59 『 體育 』  高中鋁聯／登板腎上腺素升！穀保賴沅晏滿壘拆彈成功
# 2019/12/09 18:58 『 政治 』  美麗島民調／蔡賴配總統支持度領先　民眾黨、時力可拿3席不分區立委
# 2019/12/09 18:56 『 體育 』  冬盟／「小張泰山」劉基鴻敲第2轟　張泰山希望他是他
# 2019/12/09 18:56 『 財經 』  金價出現一個月內最大跌幅　高盛：明年會攀至1600美元
# 2019/12/09 18:55 『 財經 』  台指期再創歷史新高　分析師：月底結算前都是偏多震盪
# 2019/12/09 18:52 『 影劇 』  「人在做，青峰在看」... 吳青峰震撼預告歌迷：我總會消失！
# 2019/12/09 18:48 『 3C家電 』  資料只有紙本好麻煩？上傳Google雲端、Line都可幫你秒轉文字檔
# 2019/12/09 18:48 『 影劇 』  歷經低潮...鄧紫棋浴火重生「披獸衣」驚喜宣布好消息！
# 2019/12/09 18:48 『 國際 』  英國百年印鈔廠瀕臨破產　曾負責全球1/3的貨幣印刷
# 2019/12/09 18:47 『 國際 』  全球最年輕總理！芬蘭34歲正妹總理...由同志雙親養大：曬彩虹照力挺母
# 2019/12/09 18:46 『 影劇 』  被爆拿400萬「利誘老婆生兒子」！　郭富城護妻霸氣回應…網讚爆：說得真好
# 2019/12/09 18:43 『 體育 』  高中鋁聯／美和施宗佑1安打完封高苑　畢業後想挑戰職棒
# 2019/12/09 18:43 『 體育 』  富邦U18明日之星大賽12月開打　青棒菁英比人氣
# 2019/12/09 18:42 『 國際 』  快訊／世界反禁藥組織「重判4年」！　俄羅斯國家隊東京奧運禁止出賽
# 2019/12/09 18:41 『 遊戲 』  鋼彈迷趁蜜月到日本尋十年遊戲機    老婆：那我呢？
# 2019/12/09 18:40 『 影劇 』  布丁姐姐陳櫻文生下第3子！　剖腹迎接「小麻糬」誕生：謝謝大家祝福
# 2019/12/09 18:39 『 體育 』  CBA／林書豪動怒！北京全場為吉喆默哀竟有球迷「亂入」找他自拍
# ...

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
'''
Your Code
'''
dicts = {}
for i in soup.find(class_ = 'part_list_2').find_all('h3'):
    if not i.find_all("em")[0].text in dicts:
        category_name = i.find_all("em")[0].text
        category.append(category_name)
        dicts[category_name] = []
        dicts[category_name].append(i.find_all("a")[0].text)
    else:
        category_name = i.find_all("em")[0].text
        dicts[category_name].append(i.find_all("a")[0].text)
dicts
# Out:
# {'體育': ['高中鋁聯／登板腎上腺素升！穀保賴沅晏滿壘拆彈成功',
#   '冬盟／「小張泰山」劉基鴻敲第2轟\u3000張泰山希望他是他',
#   '高中鋁聯／美和施宗佑1安打完封高苑\u3000畢業後想挑戰職棒',
#   '富邦U18明日之星大賽12月開打\u3000青棒菁英比人氣',
#   'CBA／林書豪動怒！北京全場為吉喆默哀竟有球迷「亂入」找他自拍',
#   '馬大偉運彩解盤／NBA灰狼@太陽  挺莊買太陽',
#   '高中鋁聯／U18改7局制\u3000平鎮教頭：變數變小、每局關鍵',
#   'FILA 經典神鞋夢幻展開\u3000解構絕對領域打造完美比例',
#   '冬盟／王建民訓練營精進自己\u3000吳睿勝感謝葉總那一通電話',
#   '大專棒聯／8強名單出爐\u3000文化、嘉大3勝晉級',
#   '大專棒聯／B組預賽最後一天\u3000美和再見安氣走大同晉複賽',
#   '高中鋁聯／羅浩晨開轟以王柏融激勵\u3000曾子祐欣賞坂本勇人',
#   '羅瑞歸隊暴龍3連敗嗆費城迷「來找我」\u3000恩比德對北國軍團僅拿10分',
#   '新北運動聚點Easy Gym開幕\u3000運動照護新觀念提供舒適空間',
#   '高中鋁聯／培養黃保羅扛先發\u3000先被平鎮學長震撼教育'],
#  '政治': ['美麗島民調／蔡賴配總統支持度領先\u3000民眾黨、時力可拿3席不分區立委',
#   '獨家專訪／陳玉珍頭劇痛無法下床需用尿盆\u3000淚駁被黃昭順夾手住院',
#   '網路抹黑抹紅之亂\u3000台南藍軍怒問：民進黨選情告急嗎？\u3000綠營反問夾到手還是腦袋？'],
#  '財經': ['金價出現一個月內最大跌幅\u3000高盛：明年會攀至1600美元',
#   '台指期再創歷史新高\u3000分析師：月底結算前都是偏多震盪',
#   '5G資費怎麼訂？亞太電：提價、等價升速但吃不飽',
#   '松江南京帶風向！世貿三館地上權農曆年前公告招標\u3000專家預期：搶翻了',
#   '網友落淚狂推「轟吧！台灣」！中信再推兄弟球星一日教練\u3000助少棒球員邁向選手',
#   '中華電攜手Nokia\u3000在南寮漁港完成首座5G小基站智慧路燈建置測試'],
# ...

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
'''
Your Code
'''
n = 0
l = 0
for k in dicts:
    m = len(dicts[k])
    if m > n:
        n = m
        l = k
        
print(f'Max Article Count of Catogory : {l} : {len(dicts[l])}')
# Out:
# Max Article Count of Catogory : 體育 : 15
